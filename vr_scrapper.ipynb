# %%
import pandas as pd
import numpy as np
import datetime
import glob
import re 
import os

# %%
#makes floats diplay commas and two decimals
pd.options.display.float_format = '{:,.2f}'.format

# makes ints display commas 
class _IntArrayFormatter(pd.io.formats.format.GenericArrayFormatter):

    def _format_strings(self):
        formatter = self.formatter or (lambda x: ' {:,}'.format(x))
        fmt_values = [formatter(x) for x in self.values]
        return fmt_values

pd.io.formats.format.IntArrayFormatter = _IntArrayFormatter

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Scraping the Links
# I'm scraping all of the Voter Registration Statistics table rows and putting the date, title, and link into the vr_tbl.csv file. I'm going to use the file to loop through the links to get to the files.

# %%
from requests_html import HTML, HTMLSession
import csv
import urllib

# %%
# csv_file = open('vr_tbl.csv', 'w', newline='')
# csv_writer = csv.writer(csv_file)
# csv_writer.writerow(['date', 'title', 'link'])

# Go to https://elections.wi.gov/index.php/publications/statistics/registration
session = HTMLSession()
r = session.get('https://elections.wi.gov/index.php/publications/statistics/registration')

# %%
table = r.html.find('tbody', first=True)

# %%
rows = table.find('tr')

# %%
print(rows[0].text)
# Out:
# March 1, 2021 Voter Registration Statistics
# 03/01/2021

# %%
print(rows[0].find('time', first=True).text)
# Out:
# 03/01/2021

# %%
print(rows[0].find('a', first=True).text)
# Out:
# March 1, 2021 Voter Registration Statistics

# %%
most_recent = rows[0].find('a', first=True).attrs['href']

# %%
for row in rows:
    date = row.find('time', first=True).text
    print(date)
    
    title = row.find('a', first=True).text
    print(title)
    
    link = row.find('a', first=True).attrs['href']
    print(link)
# Out:
# 03/01/2021
# March 1, 2021 Voter Registration Statistics
# /node/7360
# 02/01/2021
# February 1, 2021 Voter Registration Statistics
# /node/7331
# 01/01/2021
# January 1, 2021 Voter Registration Statistics
# /node/7301
# 12/01/2020
# December 1, 2020 Voter Registration Statistics
# /node/7265
# 11/01/2020
# November 1, 2020 Voter Registration Statistics
# /node/7220
# 10/01/2020
# October 1, 2020 Voter Registration Statistics
# /node/7147
# 09/01/2020
# September 1, 2020 Voter Registration Statistics
# /node/7070
# 08/01/2020
# August 1, 2020 Voter Registration Statistics
# /node/6993
# 07/01/2020
# July 1, 2020 Voter Registration Statistics
# /node/6948
# 06/01/2020
# June 1, 2020 Voter Registration Statistics
# /node/6919
# 05/01/2020
# May 1, 2020 Voter Registration Statistics
# /node/6886
# 04/01/2020
# April 1, 2020 Voter Registration Statistics
# /node/6830
# 03/01/2020
# March 1, 2020 Voter Registration Statistics
# /node/6701
# 02/01/2020
# February 1, 2020 Voter Registration Statistics
# /node/6677
# 01/01/2020
# January 1, 2020 Voter Registration Statistics
# /node/6652
# 12/01/2019
# December 1, 2019 Voter Registration Statistics
# /node/6638
# 11/01/2019
# November 1, 2019 Voter Registration Statistics
# /node/6614
# 10/01/2019
# October 1, 2019 Voter Registration Statistics
# /node/6579
# 09/03/2019
# September 1, 2019 Voter Registration Statistics
# /node/6565
# 08/01/2019
# August 1, 2019 Voter Registration Statistics
# /node/6549
# 07/01/2019
# July 1, 2019 Voter Registration Statistics
# /node/6543
# 06/01/2019
# June 1, 2019 Voter Registration Statistics
# /node/6536
# 05/01/2019
# May 1, 2019 Voter Registration Statistics
# /node/6509
# 04/01/2019
# April 1, 2019 Voter Registration Statistics
# /node/6486
# 03/01/2019
# March 1, 2019 Voter Registration Statistics
# /node/6450
# 02/01/2019
# February 1, 2019 Voter Registration Statistics
# /node/6426
# 01/01/2019
# January 1, 2019 Voter Registration Statistics
# /node/6375
# 11/30/2018
# December 1, 2018 Voter Registration Statistics
# /node/6323
# 10/31/2018
# November 1, 2018 Voter Registration Statistics
# /node/6264
# 09/30/2018
# October 1, 2018 Voter Registration Statistics
# /publications/statistics/registered-voters-2018-october-1
# 08/31/2018
# September 1, 2018 Voter Registration Statistics
# /publications/statistics/registered-voters-2018-september-1
# 07/31/2018
# August 1, 2018 Voter Registration Statistics
# /publications/statistics/registered-voters-2018-august-1
# 06/30/2018
# July 1, 2018 Voter Registration Statistics
# /publications/statistics/registered-voters-2018-july-1
# 05/31/2018
# June 1, 2018 Voter Registration Statistics
# /publications/statistics/registered-voters-2018-june-1
# 04/30/2018
# May 1, 2018 Voter Registration Statistics
# /publications/statistics/registered-voters-2018-may-1
# 04/01/2018
# April 1, 2018 Voter Registration Statistics
# /publications/statistics/registered-voters-2018-april-1
# 02/28/2018
# March 1, 2018 Voter Registration Statistics
# /publications/statistics/registered-voters-2018-march-1
# 01/31/2018
# February 1, 2018 Voter Registration Statistics
# /publications/statistics/registered-voters-2018-february-1
# 12/31/2017
# January 1, 2018 Voter Registration Statistics
# /publications/statistics/registered-voters-2018-january-1
# 11/30/2017
# December 1, 2017 Voter Registration Statistics
# /publications/statistics/registered-voters-2017-december-1
# 10/31/2017
# November 1, 2017 Voter Registration Statistics
# /publications/statistics/registered-voters-2017-november-1
# 09/30/2017
# October 1, 2017 Voter Registration Statistics
# /publications/statistics/registered-voters-2017-october-1
# 08/31/2017
# September 1, 2017 Voter Registration Statistics
# /publications/statistics/registered-voters-2017-september-1
# 07/31/2017
# August 1, 2017 Voter Registration Statistics
# /publications/statistics/registered-voters-2017-august-1
# 06/30/2017
# July 1, 2017 Voter Registration Statistics
# /publications/statistics/registered-voters-2017-july-1
# 05/31/2017
# June 1, 2017 Voter Registration Statistics
# /publications/statistics/registered-voters-2017-june-1
# 04/30/2017
# May 1, 2017 Voter Registration Statistics
# /publications/statistics/registered-voters-2017-may-1
# 04/02/2017
# April 3, 2017 Voter Registration Statistics
# /publications/statistics/registered-voters-2017-april-3
# 02/28/2017
# March 1, 2017 Voter Registration Statistics
# /publications/statistics/registered-voters-2017-march-1
# 01/31/2017
# February 1, 2017 Voter Registration Statistics
# /publications/statistics/registered-voters-2017-february-1
# 12/27/2016
# December 28, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-december-28
# 12/06/2016
# December 7, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-december-7
# 11/15/2016
# November 16, 2016 Voter Registration Statistics
# /node/4420
# 11/01/2016
# November 2, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-november-2
# 10/25/2016
# October 26, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-october-26
# 10/18/2016
# October 19, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-october-19
# 09/30/2016
# October 1, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-october-1
# 08/31/2016
# September 1, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-september-1
# 07/31/2016
# August 1, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-august-1
# 06/30/2016
# July 1, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-july-1
# 05/31/2016
# June 1, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-june-1
# 04/30/2016
# May 1, 2016 Voter Registration Statistics -- Corrected
# /publications/statistics/registered-voters-2016-may-1
# 04/05/2016
# April 1, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-april-1
# 03/24/2016
# March 25, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-march-25
# 01/03/2016
# January 1, 2016 Voter Registration Statistics
# /publications/statistics/registered-voters-2016-january
# 10/31/2015
# November 1, 2015 Voter Registration Statistics
# /publications/statistics/registered-voters-2015-november
# 09/30/2015
# October 1, 2015 Voter Registration Statistics
# /publications/statistics/registered-voters-2015-october
# 07/31/2015
# August 1, 2015 Voter Registration Statistics
# /publications/statistics/registered-voters-2015-august
# 06/30/2015
# July 1, 2015 Voter Registration Statistics
# /publications/statistics/registered-voters-2015-july
# 05/31/2015
# June 1, 2015 Voter Registration Statistics
# /publications/statistics/registered-voters-2015-june
# 04/30/2015
# May 1, 2015 Voter Registration Statistics
# /publications/statistics/registered-voters-2015-may
# 03/31/2015
# April 1, 2015 Voter Registration Statistics
# /publications/statistics/registered-voters-2015-April
# 02/28/2015
# March 1, 2015 Voter Registration Statistics
# /publications/statistics/registered-voters-2015-March
# 01/31/2015
# February 1, 2015 Voter Registration Statistics
# /publications/statistics/registered-voters-2015-February
# 12/31/2014
# January 1, 2015 Voter Registration Statistics
# /publications/statistics/registered-voters-2015-January
# 11/30/2014
# December 1, 2014 Voter Registration Statistics
# /publications/statistics/registered-voters-2014-December
# 10/31/2014
# November 1, 2014 Voter Registration Statistics
# /publications/statistics/registered-voters-2014-November
# 09/30/2014
# October 1, 2014 Voter Registration Statistics
# /publications/statistics/registered-voters-2014-October
# 08/31/2014
# September 1, 2014 Voter Registration Statistics
# /publications/statistics/registered-voters-2014-September
# 07/31/2014
# August 1, 2014 Voter Registration Statistics
# /publications/statistics/registered-voters-2014-August
# 06/30/2014
# July 1, 2014 Voter Registration Statistics
# /publications/statistics/registered-voters-2014-July
# 05/31/2014
# June 1, 2014 Voter Registration Statistics
# /publications/statistics/registered-voters-2014-June
# 04/30/2014
# May 1, 2014 Voter Registration Statistics
# /publications/statistics/registered-voters-2014-May
# 03/31/2014
# April 1, 2014 Voter Registration Statistics
# /publications/statistics/registered-voters-2014-April
# 02/28/2014
# March 1, 2014 Voter Registration Statistics
# /publications/statistics/registered-voters-2014-March
# 01/31/2014
# February 1, 2014 Voter Registration Statistics
# /publications/statistics/registered-voters-2014-february
# 12/31/2013
# January 1, 2014 Voter Registration Statistics
# /publications/statistics/registered-voters-2014-january
# 11/30/2013
# December 1, 2013 Voter Registration Statistics
# /publications/statistics/registered-voters-2013-December
# 11/04/2013
# November 5, 2013 Voter Registration Statistics
# /publications/statistics/registered-voters-2013-November
# 09/17/2013
# September 18, 2013 Voter Registration Statistics
# /publications/statistics/registered-voters-2013-september
# 07/31/2013
# August 1, 2013 Voter Registration Statistics
# /publications/statistics/registered-voters-2013-august
# 06/30/2013
# July 1, 2013 Voter Registration Statistics
# /publications/statistics/registered-voters-2013-july
# 06/02/2013
# June 1, 2013 Voter Registration Statistics
# /publications/statistics/registered-voters-2013-june
# 04/30/2013
# May 1, 2013 Voter Registration Statistics
# /publications/statistics/registered-voters-2013-may
# 03/31/2013
# April 1, 2013 Voter Registration Statistics
# /publications/statistics/registered-voters-2013-april
# 02/28/2013
# March 1, 2013 Voter Registration Statistics
# /publications/statistics/registered-voters-2013-march
# 01/31/2013
# February 1, 2013 Voter Registration Statistics
# /node/2747
# 01/03/2013
# January 4, 2013 Voter Registration Statistics
# /publications/statistics/registered-voters-2013-january
# 12/02/2012
# December 3, 2012 Voter Registration Statistics
# /publications/statistics/registered-voters-2012-december
# 11/04/2012
# November 5, 2012 Voter Registration Statistics
# /publications/statistics/registered-voters-2012-nov
# 10/18/2012
# October 19, 2012 Voter Registration Statistics
# /publications/statistics/registered-voters-2012-oct-19
# 10/07/2012
# October 8, 2012 Voter Registration Statistics
# /publications/statistics/registered-voters-2012-october
# 09/27/2012
# September 2012 Voter Registration Statistics
# /publications/statistics/registered-voters-2012-september
# 08/08/2012
# August 2012 Voter Registration Statistics
# /publications/statistics/registered-voters-2012-august
# 02/07/2012
# February 2012 Voter Registration Statistics
# /publications/statistics/registered-voters-2012-feb
# 07/12/2011
# July 2011 Voter Registration Statistics
# /publications/statistics/registered-voters-2011-july
# 12/27/2010
# December 2010 Voter Registration Statistics
# /publications/statistics/registered-voters-2010-december
# 10/19/2010
# Fall 2010 Voter Registration Statistics - Pre-Election
# /publications/statistics/registered-voters-2010-fall-pre-election
# 04/02/2009
# April 2009 Voter Registration Statistics
# /publications/statistics/registered-voters-2009-april
# 10/30/2008
# October 2008 Voter Registration Statistics
# /publications/statistics/registered-voters-2008-october

# %%
csv_writer.writerow([date, title, link])
    
csv_file.close()

# %% [markdown]
# ## Loop to Download the Files

# %%
starter_url = 'http://elections.wi.gov'
date_pattern = re.compile(r'(\d{2})/(\d{2})/(\d{4})')

# %%
import time
from csv import reader

# %%
with open('vr_tbl.csv', 'r') as read_obj:
    csv_reader = reader(read_obj)
    header = next(csv_reader)
    for row in csv_reader:
        date = date_pattern.sub(r'\3\1\2', row[0])
        path = row[2]
        url = starter_url + path

        month = session.get(url)

        table = month.html.find('tbody', first=True)

        file_rows = table.find('tr')
        for file_row in file_rows:
            title = file_row.find('a', first=True).text
            #print(title)
            file = file_row.find('a', first=True).attrs['href']\
            
            if re.search(r'xlsx', title):
                if re.search(r'[c|C]ounty', title):
                    #print(title)
                    f = session.get(file)
                    with open('county\\{}.xlsx'.format(date), 'wb') as outfile:
                        outfile.write(f.content)
                elif re.search(r'[w|W]ard', title):
                    #print(title)
                    f = session.get(file)
                    with open('muni\\{}.xlsx'.format(date), 'wb') as outfile:
                        outfile.write(f.content)
                elif re.search(r'[c|C]ong', title):
                    f = session.get(file)
                    with open('congressional\\{}.xlsx'.format(date), 'wb') as outfile:
                        outfile.write(f.content)
                elif re.search(r'[a|A]ssembly', title):
                    f = session.get(file)
                    with open('assembly\\{}.xlsx'.format(date), 'wb') as outfile:
                        outfile.write(f.content)
                elif re.search(r'[s|S]enate', title):
                    f = session.get(file)
                    with open('senate\\{}.xlsx'.format(date), 'wb') as outfile:
                        outfile.write(f.content)
                elif re.search(r'[a|A]ge', title):
                    f = session.get(file)
                    with open('age group\\{}.xlsx'.format(date), 'wb') as outfile:
                        outfile.write(f.content)
                elif re.search(r'[s|S]ummary', title):
                    f = session.get(file)
                    with open('summary\\{}_Voter_Registration_Summary_Statistics.xlsx'.format(date), 'wb') as outfile:
                        outfile.write(f.content)
            time.sleep(1)
        #time.sleep(2)

# %% [markdown]
# ## Starting the Timeline
# Using 20160430_Voter_Registration_Summary_Statistics.xlsx to start the VR timeline. BTW, Voters by Senate tab has a trailing space in it. Just delete the space in the file within Excel

# %%
# meant for County, Congressional, Senate, and Assembly
def start(geography):
    # Voters by Senate tab has a trailing space in it. Just delete the space in the file within Excel
    start = pd.read_excel('summary\\20160430_Voter_Registration_Summary_Statistics.xlsx', 'Voters by {}'.format(geography))

    start.rename(columns={'05/01/20152': '05/01/2015'}, inplace=True)
    start.rename(columns={'42,461':'01/04/2016'}, inplace=True)
    start.set_index(start.columns[0], inplace=True)
    
    if start.index.name == 'Date':
        start = start.transpose()
    
    start.dropna(axis='columns', how='all', inplace=True)
    start.columns = pd.to_datetime(start.columns)
    start = start[start.columns.sort_values()]
    
    # extract district numbers
    # exclude Age Group bc it has numbers for its groups
    if (geography != 'Age Group') and (re.search(r'\d+', start.index[3])): # use 'and' instead of '&'
        start.index = start.index.str.extract(r'(\d+)')[0]
        start.index = start.index.astype(str).str.zfill(2)
    return start

# %% [markdown]
# ## Looping through Files

# %%
# use county, state_senate, state_assembly
def end(folder):
    end_files = glob.glob('{}\\*'.format(folder))

    dfs = []
    for file in end_files:
        end = pd.read_excel(file)
        # for each temp df, drop N/A columns
        if folder == 'age group':
            end.dropna(axis='index', thresh=2, inplace=True)
        end.dropna(axis='columns', how='all', inplace=True)

        # find header
        header_index = end[end.columns[0]].first_valid_index()
        
        # age group rly gave me a hard time
        if folder == 'age group':
            header = end.iloc[0]
            end.columns = header
        else:
            if header_index != 0: #checks for useless top rows
                end = end[header_index:] #splice off useless top rows

                #drop N/A rows and columns
                end.dropna(axis='index', how='all', inplace=True) 
                end.dropna(axis='columns', how='all', inplace=True) 

                #set header
                if end.iloc[0].isnull().values.any(): #senate data gave me a hard time
                    end.drop(header_index, axis=0, inplace=True)
                header = end.iloc[0]
                end.columns = header 
                end = end[1:]

        # drop code col and append to dfs
        #print(end)
        if folder == 'county':
            end = end.drop(end.columns[0], axis=1)
            end.set_index(end.columns[0], inplace=True)
        elif folder == 'age group':
            end.set_index(end.columns[0], inplace=True)
        else:
            end.set_index(end.columns[0], inplace=True)
            # extract district numbers
            end.index = end.index.str.extract(r'(\d+)')[0]
            end.index = end.index.astype(str).str.zfill(2)
        #print(end)
        end = end.iloc[:,-1:]
        end.rename(columns={end.columns[0]:re.findall(r'\d+', file)[0]}, inplace=True)
        
        dfs.append(end)

    #print(dfs)
    all_end = pd.concat(dfs, axis=1, join='outer')
    all_end.dropna(axis='index', how='any', inplace=True)

    all_end.columns = pd.to_datetime(all_end.columns)
    all_end = all_end[all_end.columns.sort_values()]
    
#     # extract district numbers
#     if (folder != 'age group') and re.search(r'\d+', all_end.index[3]):
#         all_end.index = all_end.index.str.extract(r'(\d+)')[0]
    
    st = start(folder.title())
    
    # makes joining senate data possible
    st.index.name = folder.title()
    all_end.index.name = folder.title()
   
    end = pd.merge(st, all_end, on=all_end.index.name)

    end = end[end.columns.sort_values()]
    
    # remove timestamps
    end.columns = pd.to_datetime(end.columns).date
    
    # remove monthly dupes
    end = end.loc[:, ~pd.to_datetime(end.columns).strftime('%y-%m').duplicated()]
    
    end.loc['*Total',:] = end.sum(axis=0).astype(int)
    
    end.sort_index(inplace=True)
        
    # make everything into a float so that diff() works
    end = end.astype(float)

    return end

# %%
cty = end('county')
sd = end('senate')
ad = end('assembly')
cd = end('congressional')
age = end('age group')

# %%
cty.to_csv('upload2gsheet\\vr_county.csv')
sd.to_csv('upload2gsheet\\vr_senate.csv')
ad.to_csv('upload2gsheet\\vr_assembly.csv')
cd.to_csv('upload2gsheet\\vr_congressional.csv')
age.to_csv('upload2gsheet\\vr_age.csv')

# %%
d2g.upload(cty, spreadsheet_key, 'County', credentials=credentials, row_names=True)
d2g.upload(cd, spreadsheet_key, 'CD', credentials=credentials, row_names=True)
d2g.upload(sd, spreadsheet_key, 'SD', credentials=credentials, row_names=True)
d2g.upload(ad, spreadsheet_key, 'AD', credentials=credentials, row_names=True)
d2g.upload(age, spreadsheet_key, 'Age', credentials=credentials, row_names=True)
# Out:
# <Worksheet 'Age' id:211692979>

# %% [markdown]
# ### Municipalities

# %%
# keys are meant for attaching the geography's name to the merged df
muni_key = pd.read_csv('muni_key.csv')
muni_key['Hindi'] = muni_key['Hindi'].astype(int)
muni_key['Hindi'] = muni_key['Hindi'].astype(str)
muni_key['Hindi'] = muni_key['Hindi'].str.zfill(5)
muni_key.set_index('Hindi', inplace=True)

# %%
files = glob.glob('muni\\*')

# %%
dfs = []
for fn in files:
    file = pd.read_excel(fn)
    # for each temp df, drop N/A columns
    file.dropna(axis='columns', how='all', inplace=True)
    
    # find header
    header_index = file[file.columns[0]].first_valid_index()
    
    if header_index != 0: #checks for useless top rows
        file = file[header_index:] #splice off useless top rows

        #drop N/A rows and columns
        file.dropna(axis='index', how='all', inplace=True) 
        file.dropna(axis='columns', how='all', inplace=True) 

        #set header
        #file.drop(header_index, axis=0, inplace=True)
        header = file.iloc[0]
        file.columns = header 
        file.dropna(axis='index', how='all', inplace=True) 
      
        if (file.columns.to_series() == file.iloc[0]).all():
            file = file[1:]
    else:
        if (file.columns.str.contains('^Unnamed')).any():
            file.columns = file.iloc[0]
            file = file[1:]
    
    
    file.set_index(file.filter(regex=(r'(Hindi)|(HINDI)')).columns[0], inplace=True)
    file.index.name = file.index.name.title()
    file.index = file.index.astype(int)
    file.index = file.index.astype(str)
    file.index = file.index.str.zfill(5)
    
    file.rename(columns={file.columns[-1]:re.findall(r'\d+', fn)[0]}, inplace=True)
    
    #file = file[file.columns[-1]]
    file = file.groupby(['Hindi']).aggregate({file.columns[-1]:'sum'})

    dfs.append(file)

# %%
all_mn = pd.concat(dfs, axis=1, join='outer')

all_mn.columns = pd.to_datetime(all_mn.columns).date
all_mn = all_mn[all_mn.columns.sort_values()]

# remove monthly dupes
all_mn = all_mn.loc[:, ~pd.to_datetime(all_mn.columns).strftime('%y-%m').duplicated()]

# make everything into a float so that diff() works
all_mn = all_mn.astype(float)

# %%
muni = pd.concat([muni_key, all_mn], axis=1)
muni = muni.sort_index()

# %%
muni.loc['*Total',:] = muni.sum(axis=0).astype(int)
muni['*Mean'] = muni.mean(axis=1).astype(int)
muni.sort_index(inplace=True)

# %%
muni.sort_values(by='*Mean', ascending=False, inplace=True)

# %%
muni['row_num'] = range(len(muni))

muni['Muni'] = muni['row_num'].astype(str).str.zfill(4) + '. ' + muni['Muni']

muni.drop(columns = ['*Mean', 'row_num'], inplace=True)

# %%
d2g.upload(muni, spreadsheet_key, 'Municipality', credentials=credentials, row_names=True)
# Out:
# <Worksheet 'Municipality' id:575947317>

# %%
muni.to_csv('upload2gsheet\\vr_muni.csv')

# %% [markdown]
# ## Calculating Changes

# %%
cty_diff = cty.diff(axis=1)
sd_diff = sd.diff(axis=1)
ad_diff = ad.diff(axis=1)
cd_diff = cd.diff(axis=1)
age_diff = age.diff(axis=1)

# %%
cty_diff.to_csv('upload2gsheet\\vrdiff_county.csv')
sd_diff.to_csv('upload2gsheet\\vrdiff_senate.csv')
ad_diff.to_csv('upload2gsheet\\vrdiff_assembly.csv')
cd_diff.to_csv('upload2gsheet\\vrdiff_congressional.csv')
age_diff.to_csv('upload2gsheet\\vrdiff_age.csv')

# %%
muni_diff = muni.iloc[:, 2:].diff(axis=1)

# %%
muni_diff = pd.concat([muni_key, muni_diff], axis=1)
muni_diff = muni_diff.sort_index()
muni_diff = pd.concat([muni_diff.iloc[[len(muni_diff)-1],:], muni_diff.drop('*Total', axis=0)], axis=0, copy=False)

# %%
muni_diff.to_csv('vrdiff_muni.csv')

# %%
muni_diff
# Out:
#              County                                    Muni  2013-06-30  \
# Hindi
# 72291   WOOD COUNTY  CITY OF WISCONSIN RAPIDS - WOOD COUNTY         NaN
# 01002  ADAMS COUNTY            TOWN OF ADAMS - ADAMS COUNTY         NaN
# 01004  ADAMS COUNTY        TOWN OF BIG FLATS - ADAMS COUNTY         NaN
# 01006  ADAMS COUNTY          TOWN OF COLBURN - ADAMS COUNTY         NaN
# 01008  ADAMS COUNTY     TOWN OF DELL PRAIRIE - ADAMS COUNTY         NaN
# ...             ...                                     ...         ...
# 72186   WOOD COUNTY         VILLAGE OF VESPER - WOOD COUNTY         NaN
# 72251   WOOD COUNTY  CITY OF MARSHFIELD - MULTIPLE COUNTIES         NaN
# 72261   WOOD COUNTY           CITY OF NEKOOSA - WOOD COUNTY         NaN
# 72271        1.00        7.00       12.00       13.00       -3.00       -4.00
# 72291      188.00      337.00      295.00      409.00      -11.00      -37.00
#
# [1910 rows x 75 columns]

# %%
d2g.upload(cty_diff, spreadsheet_key, 'County Shift', credentials=credentials, row_names=True)
d2g.upload(cd_diff, spreadsheet_key, 'CD Shift', credentials=credentials, row_names=True)
d2g.upload(sd_diff, spreadsheet_key, 'SD Shift', credentials=credentials, row_names=True)
d2g.upload(ad_diff, spreadsheet_key, 'AD Shift', credentials=credentials, row_names=True)
d2g.upload(age_diff, spreadsheet_key, 'Age Shift', credentials=credentials, row_names=True)
# Out:
# <Worksheet 'Age Shift' id:2112800033>

# %%
# have to reset_index due to an error
d2g.upload(muni_diff.reset_index(), spreadsheet_key, 'Municipality Shift', credentials=credentials, row_names=True)
# Out:
# <Worksheet 'Municipality Shift' id:142913538>

# %% [markdown]
# ## Verticalize
# Prepare dfs for Tableau visualization

# %%
def vert(hori):
    ver = hori.transpose().copy()
    
    if hori.columns[1] == 'Muni':
        ver.columns = ver.loc['Muni']
        ver = ver.iloc[2:]

        ver.rename(columns={np.nan: '*Total'}, inplace=True)
    
    ver.index.rename('Date', inplace=True)
    ver.columns = ver.columns.str.zfill(2)
    
    ver_diff = ver.diff()
    ver_pct = ver.pct_change()
    
    ver['Type'] = 'Population'
    ver_diff['Type'] = 'Shifts'
    ver_pct['Type'] = 'Shifts %'
    
    all_ver = pd.concat([ver, ver_diff, ver_pct])

    return all_ver

# %%
def stack(hori):
    ver = vert(hori)
    
    stack = ver.reset_index().melt(['Date', 'Type'])

    stack.set_index('Date', inplace=True)
    return stack

# %%
cty_ver = vert(cty)
sd_ver = vert(sd)
ad_ver = vert(ad)
cd_ver = vert(cd)
age_ver = vert(age)

# %%
muni_ver = vert(muni)

# %%
cty_stack = stack(cty)
sd_stack = stack(sd)
ad_stack = stack(ad)
cd_stack = stack(cd)
age_stack = stack(age)

# %%
priority_cty = ['MILWAUKEE COUNTY', 'DANE COUNTY', 'WAUKESHA COUNTY', 'OZAUKEE COUNTY', 'WASHINGTON COUNTY', 'BROWN COUNTY', 'OUTAGAMIE COUNTY', 'WINNEBAGO COUNTY', 'KENOSHA COUNTY', 'RACINE COUNTY']

# %%
cty_stack.loc[cty_stack['County'].isin(priority_cty), 'Key'] = 'Yes'

# %%
cty_stack.query('Key == "Yes"')
# Out:
#                   Type            County      value  Key
# Date
# 2009-07-01  Population      BROWN COUNTY 139,194.00  Yes
# 2010-08-02  Population      BROWN COUNTY 138,186.00  Yes
# 2010-12-28  Population      BROWN COUNTY 141,849.00  Yes
# 2011-09-01  Population      BROWN COUNTY 137,322.00  Yes
# 2011-11-01  Population      BROWN COUNTY 137,099.00  Yes
# ...                ...               ...        ...  ...
# 2020-10-01    Shifts %  WINNEBAGO COUNTY       0.03  Yes
# 2020-11-01    Shifts %  WINNEBAGO COUNTY       0.02  Yes
# 2020-12-01    Shifts %  WINNEBAGO COUNTY       0.04  Yes
# 2021-01-01    Shifts %  WINNEBAGO COUNTY      -0.00  Yes
# 2021-02-01    Shifts %  WINNEBAGO COUNTY      -0.01  Yes
#
# [3150 rows x 4 columns]

# %%
cty_stack.to_csv('tableau_prep\\vr_county_stack.csv')
sd_stack.to_csv('tableau_prep\\vr_senate_stack.csv')
ad_stack.to_csv('tableau_prep\\vr_assembly_stack.csv')
cd_stack.to_csv('tableau_prep\\vr_cd_stack.csv')
age_stack.to_csv('tableau_prep\\vr_age_stack.csv')

# %%
muni_stack = stack(muni)

# %%
priority_muni = ['0010. CITY OF JANESVILLE - ROCK COUNTY', '0009. CITY OF OSHKOSH - WINNEBAGO COUNTY', '0008. CITY OF RACINE - RACINE COUNTY', '0007. CITY OF APPLETON - MULTIPLE COUNTIES', '0006. CITY OF WAUKESHA - WAUKESHA COUNTY', '0005. CITY OF EAU CLAIRE - MULTIPLE COUNTIES', '0004. CITY OF KENOSHA - KENOSHA COUNTY', '0003. CITY OF GREEN BAY - BROWN COUNTY', '0002. CITY OF MADISON - DANE COUNTY', '0001. CITY OF MILWAUKEE - MULTIPLE COUNTIES']

# %%
muni_stack
# Out:
#                   Type    Muni       value
# Date
# 2013-06-30  Population  *Total 3,400,807.0
# 2013-07-31  Population  *Total 3,398,833.0
# 2013-09-17  Population  *Total 3,394,795.0
# 2013-11-04  Population  *Total 3,392,508.0
# 2014-08-31  Population  *Total 3,380,325.0
# ...                ...     ...         ...
# 2020-10-01    Shifts %  *Total         0.0
# 2020-11-01    Shifts %  *Total         0.0
# 2020-12-01    Shifts %  *Total         0.0
# 2021-01-01    Shifts %  *Total         0.0
# 2021-02-01    Shifts %  *Total         0.0
#
# [418290 rows x 3 columns]

# %%
muni_stack.loc[muni_stack['Muni'].isin(priority_muni), 'Key'] = 'Yes'

# %%
muni_stack.query('Key == "Yes"')
# Out:
#                   Type                                         Muni     value  \
# Date
# 2013-06-30  Population  0001. CITY OF MILWAUKEE - MULTIPLE COUNTIES 321,577.0
# 2013-07-31  Population  0001. CITY OF MILWAUKEE - MULTIPLE COUNTIES 321,459.0
# 2013-09-17  Population  0001. CITY OF MILWAUKEE - MULTIPLE COUNTIES 320,907.0
# 2013-11-04  Population  0001. CITY OF MILWAUKEE - MULTIPLE COUNTIES 320,681.0
# 2014-08-31  Population  0001. CITY OF MILWAUKEE - MULTIPLE COUNTIES 318,186.0
# ...                ...                                          ...       ...
# 2020-10-01    Shifts %       0010. CITY OF JANESVILLE - ROCK COUNTY      0.04
# 2020-11-01    Shifts %       0010. CITY OF JANESVILLE - ROCK COUNTY      0.03
# 2020-12-01    Shifts %       0010. CITY OF JANESVILLE - ROCK COUNTY      0.03
# 2021-01-01    Shifts %       0010. CITY OF JANESVILLE - ROCK COUNTY       0.0
# 2021-02-01    Shifts %       0010. CITY OF JANESVILLE - ROCK COUNTY      -0.0
#
#             Key
# Date
# 2013-06-30  Yes
# 2013-07-31  Yes
# 2013-09-17  Yes
# 2013-11-04  Yes
# 2014-08-31  Yes
# ...         ...
# 2020-10-01  Yes
# 2020-11-01  Yes
# 2020-12-01  Yes
# 2021-01-01  Yes
# 2021-02-01  Yes
#
# [1752 rows x 4 columns]

# %%
muni_stack.to_csv('tableau_prep\\vr_muni_stack.csv')
